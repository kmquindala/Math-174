# %% [markdown]
# # Introduction to Numerical Analysis I

# %% [markdown]
# In this course, we will learn how to:
# 1. Create and analyze algorithms.
# 2. Compute the error associated to the algorithm.

# %%
for i in range(1,5):
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# Typeset math using Latex codes:

# %% [markdown]
# $\begin{pmatrix}
#   1 & 0\\
#   0 & 1
#   \end{pmatrix}$

# %%
import numpy as np
import matplotlib.pyplot as plt
x = [-5,-2,0,1,3]
y = [2,-1,1,-4,3]
plt.plot(x,y)
plt.show()

# %% [markdown]
# If you are ready for the quiz, click the link:
# https://classroom.google.com/u/0/c/MTE3OTE0NTEwMTQ2/a/MTE3OTE0NTEwMTc0/details
